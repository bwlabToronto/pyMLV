# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
import cv2
sys.path.append('../')  # Adds the root directory to Python's module search path
from MLVcode.drawLinedrawing import drawLinedrawing

# %%
filename = "../images/example.jpg"
# Plot the image
image = cv2.imread(filename)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
# Convert the photograph into line drawing
vecLD = traceLineDrawing(filename)

# View the line drawing
drawLineDrawing(vecLD)

# overlay line drawing onto the image
plt.imshow(image)
drawLineDrawing(vecLD, 1, 'y')
